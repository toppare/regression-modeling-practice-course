# %%
import numpy as numpyp
import pandas as pd
import statsmodels.api
import statsmodels.formula.api as smf
import seaborn
import matplotlib.pyplot as plt
import scipy
# %matplotlib inline

# %%
# bug fix for display formats to avoid run time errors
pd.set_option('display.float_format', lambda x:'%.2f'%x)
#call in data set
data = pd.read_csv('nesarc_pds.csv')

# %%
for i in sorted(list(data.columns)):
    print i
# Out:
# ADULTCH
# AGE
# ALCABDEP12DX
# ALCABDEPP12DX
# ANTISOCDX2
# APANDX12
# APANDXP12
# APANLIFE
# APANSNS12
# APANSNSP12
# AVOIDPDX2
# BEERECF
# BUILDTYP
# CCS
# CDAY
# CENDIV
# CHECK321
# CHECK322
# CHECK323
# CHECK324
# CHECK325
# CHLD0
# CHLD0_17
# CHLD13_15
# CHLD16_17
# CHLD1_4
# CHLD5_12
# CKSTATUS
# CMON
# COC12ABDEP
# COCP12ABDEP
# CONDUCTONLY
# CONSUMER
# COOLECF
# CYEAR
# DAPANDXSNI12
# DAPANDXSNIP12
# DAPANDXSNIS12
# DAPANDXSNISP12
# DDYSSNI12
# DDYSSNIP12
# DDYSSNIS12
# DDYSSNISP12
# DEPPDDX2
# DGENAXDXSNI12
# DGENAXDXSNIP12
# DGENAXDXSNIS12
# DGENAXDXSNISP12
# DGPANDXSNI12
# DGPANDXSNIP12
# DGPANDXSNIS12
# DGPANDXSNISP12
# DGSTATUS
# DMAJORDEPSNI12
# DMAJORDEPSNIP12
# DMAJORDEPSNIS12
# DMAJORDEPSNISP12
# DNHYPOSNI12
# DNHYPOSNIP12
# DNHYPOSNIS12
# DNHYPOSNISP12
# DNMANDXSNI12
# DNMANDXSNIP12
# DNMANDXSNIS12
# DNMANDXSNISP12
# DOBD
# DOBM
# DOBY
# DPANDXSNI12
# DPANDXSNIP12
# DPANDXSNIS12
# DPANDXSNISP12
# DSOCPDXSNI12
# DSOCPDXSNIP12
# DSOCPDXSNIS12
# DSOCPDXSNISP12
# ...

# %%
data['MAJORDEPLIFE'] = pd.to_numeric(data['MAJORDEPLIFE'], errors='coerce')
data['NDSymptoms'] = pd.to_numeric(data['NDSymptoms'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-562c8caa4df9> in <module>()
#       1 data['MAJORDEPLIFE'] = pd.to_numeric(data['MAJORDEPLIFE'], errors='coerce')
# ----> 2 data['NDSymptoms'] = pd.to_numeric(data['NDSymptoms'], errors='coerce')
#
# /Users/barantoppare/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Users/barantoppare/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
# ...
